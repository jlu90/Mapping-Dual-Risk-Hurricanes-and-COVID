# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('./hurricanes_east_coast-copy.csv')
# Out:
# /Users/quinton/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1,2,3,8,9,14,19,20,23,24,25,161,162) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (121220, 163)

# %%
df.head()
# Out:
#              SID SEASON NUMBER BASIN SUBBASIN       NAME             ISO_TIME  \
# 0                  Year
# 1  1851175N26270   1851      5   NaN       GM  NOT_NAMED  1851-06-23 12:00:00
# 2  1851175N26270   1851      5   NaN       GM  NOT_NAMED  1851-06-23 15:00:00
# 3  1851175N26270   1851      5   NaN       GM  NOT_NAMED  1851-06-23 18:00:00
# 4  1851175N26270   1851      5   NaN       GM  NOT_NAMED  1851-06-23 21:00:00
#
#   NATURE            LAT           LON  ... BOM_GUST_PER REUNION_GUST  \
# 0         degrees_north  degrees_east  ...       second          kts
# 1     TS        26.1000      -90.4000  ...
# 2     TS        26.2001      -90.6999  ...
# 3     TS        26.3000      -91.0000  ...
# 4     TS        26.3999      -91.3001  ...
#
#   REUNION_GUST_PER USA_SEAHGT USA_SEARAD_NE USA_SEARAD_SE USA_SEARAD_SW  \
# 0           second         ft         nmile         nmile         nmile
# 1
# 2
# 3
# 4
#
#   USA_SEARAD_NW STORM_SPEED STORM_DIR
# ...

# %%
new_df = df[['SID','SEASON', 'NUMBER', 'NAME','ISO_TIME','NATURE','LAT','LON','WMO_WIND','WMO_PRES', 'WMO_AGENCY', 'DIST2LAND', 'LANDFALL', 'USA_LAT', 'USA_LON', 'USA_STATUS', 'USA_WIND', 'USA_PRES', 'USA_SSHS', 'USA_EYE', 'USA_SEAHGT', 'STORM_SPEED', 'STORM_DIR']]

# %%
pd.set_option("display.max_columns", None)

# %%
new_df.head()
# Out:
#              SID SEASON NUMBER       NAME             ISO_TIME NATURE  \
# 0                  Year
# 1  1851175N26270   1851      5  NOT_NAMED  1851-06-23 12:00:00     TS
# 2  1851175N26270   1851      5  NOT_NAMED  1851-06-23 15:00:00     TS
# 3  1851175N26270   1851      5  NOT_NAMED  1851-06-23 18:00:00     TS
# 4  1851175N26270   1851      5  NOT_NAMED  1851-06-23 21:00:00     TS
#
#              LAT           LON WMO_WIND WMO_PRES WMO_AGENCY DIST2LAND  \
# 0  degrees_north  degrees_east      kts       mb                   km
# 1        26.1000      -90.4000                                    335
# 2        26.2001      -90.6999                                    323
# 3        26.3000      -91.0000                                    312
# 4        26.3999      -91.3001                                    304
#
#   LANDFALL        USA_LAT       USA_LON USA_STATUS USA_WIND USA_PRES USA_SSHS  \
# 0       km  degrees_north  degrees_east                 kts       mb        1
# ...

# %%
new_df.shape
# Out:
# (121220, 23)

# %%
new_df.isnull().sum()
# Out:
# SID            0
# SEASON         0
# NUMBER         0
# NAME           0
# ISO_TIME       0
# NATURE         0
# LAT            0
# LON            0
# WMO_WIND       0
# WMO_PRES       0
# WMO_AGENCY     0
# DIST2LAND      0
# LANDFALL       0
# USA_LAT        0
# USA_LON        0
# USA_STATUS     0
# USA_WIND       0
# USA_PRES       0
# USA_SSHS       0
# USA_EYE        0
# USA_SEAHGT     0
# STORM_SPEED    0
# STORM_DIR      0
# dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %%
new_df[new_df['NAME']=='SANDY']
# Out:
#                   SID SEASON NUMBER   NAME             ISO_TIME NATURE  \
# 114288  2012296N14283   2012     78  SANDY  2012-10-21 18:00:00     DS
# 114289  2012296N14283   2012     78  SANDY  2012-10-21 21:00:00     DS
# 114290  2012296N14283   2012     78  SANDY  2012-10-22 00:00:00     DS
# 114291  2012296N14283   2012     78  SANDY  2012-10-22 03:00:00     DS
# 114292  2012296N14283   2012     78  SANDY  2012-10-22 06:00:00     DS
# 114293  2012296N14283   2012     78  SANDY  2012-10-22 09:00:00     DS
# 114294  2012296N14283   2012     78  SANDY  2012-10-22 12:00:00     TS
# 114295  2012296N14283   2012     78  SANDY  2012-10-22 15:00:00     TS
# 114296  2012296N14283   2012     78  SANDY  2012-10-22 18:00:00     TS
# 114297  2012296N14283   2012     78  SANDY  2012-10-22 21:00:00     TS
# 114298  2012296N14283   2012     78  SANDY  2012-10-23 00:00:00     TS
# 114299  2012296N14283   2012     78  SANDY  2012-10-23 03:00:00     TS
# ...

# %%
new_df.tail(10)
# Out:
#                   SID SEASON NUMBER    NAME             ISO_TIME NATURE  \
# 121210  2020206N11343   2020     43  ISAIAS  2020-07-28 21:00:00     DS
# 121211  2020206N11343   2020     43  ISAIAS  2020-07-29 00:00:00     DS
# 121212  2020206N11343   2020     43  ISAIAS  2020-07-29 03:00:00     DS
# 121213  2020206N11343   2020     43  ISAIAS  2020-07-29 06:00:00     DS
# 121214  2020206N11343   2020     43  ISAIAS  2020-07-29 09:00:00     DS
# 121215  2020206N11343   2020     43  ISAIAS  2020-07-29 12:00:00     DS
# 121216  2020206N11343   2020     43  ISAIAS  2020-07-29 15:00:00     DS
# 121217  2020206N11343   2020     43  ISAIAS  2020-07-29 18:00:00     DS
# 121218  2020206N11343   2020     43  ISAIAS  2020-07-29 21:00:00     DS
# 121219  2020206N11343   2020     43  ISAIAS  2020-07-30 00:00:00     TS
#
#             LAT      LON WMO_WIND WMO_PRES WMO_AGENCY DIST2LAND LANDFALL  \
# 121210  13.9966 -56.9134                                    578      489
# ...

# %%
new_df.rename(columns = {
    "sid" : "storm_id",
    "season" : "year",
    "lat" : "latitude",
    "lon" : "longitude",
    "wmo_wind" : "wmo_wind(knots)",
    "wmo_pres" : "wmo_pressure(mb)", # World Meteorological Organization
    "dist2land" : "dist2land(km)",
    "landfall" : "landfall(km)",
    "usa_sshs" : "storm_category",
    "usa_eye" : "eye_diameter",
    "usa_seahgt" : "sea_height(ft)",
    "storm_speed" : "storm_speed(knots)",
    "storm_dir" : "storm_direction(degrees)"
    }, inplace = True)
new_df.columns = new_df.columns.str.lower()
new_df.drop(index = 0, inplace = True)
new_df.reset_index(drop = True, inplace = True)
# Out:
# /Users/quinton/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /Users/quinton/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
new_df = new_df.replace(' ', np.nan)

# %%
new_df.isnull().sum()
# Out:
# sid                 0
# season              0
# number              0
# name                0
# iso_time            0
# nature              0
# lat                 0
# lon                 0
# wmo_wind        69543
# wmo_pres       100280
# wmo_agency      69205
# dist2land           0
# landfall         2249
# usa_lat         19840
# usa_lon         19840
# usa_status      19634
# usa_wind        20511
# usa_pres        80591
# usa_sshs          484
# usa_eye        121114
# usa_seahgt     115362
# storm_speed        29
# storm_dir          29
# dtype: int64

# %%
new_df['landfall'] = new_df['landfall'].map(float)

# %%
new_df = new_df[new_df['landfall'] == 0]

# %%
new_df.to_csv('../data/hurricanes_east_coast.csv', index=False)
df = pd.read_csv('../data/hurricanes_east_coast.csv')

# %%
df.shape
# Out:
# (14214, 23)

# %%
df.head()
# Out:
#              sid  season  number       name             iso_time nature  \
# 0  1851175N26270    1851       5  NOT_NAMED  1851-06-25 21:00:00     TS
# 1  1851175N26270    1851       5  NOT_NAMED  1851-06-26 00:00:00     TS
# 2  1851175N26270    1851       5  NOT_NAMED  1851-06-26 03:00:00     TS
# 3  1851175N26270    1851       5  NOT_NAMED  1851-06-26 06:00:00     TS
# 4  1851175N26270    1851       5  NOT_NAMED  1851-06-26 09:00:00     TS
#
#        lat      lon  wmo_wind  wmo_pres  wmo_agency  dist2land  landfall  \
# 0  28.1333 -96.5667      80.0       NaN  hurdat_atl         22       0.0
# 1  28.1667 -96.8000      70.0       NaN  hurdat_atl          0       0.0
# 2  28.2265 -97.0793       NaN       NaN         NaN          0       0.0
# 3  28.3000 -97.4000      60.0       NaN  hurdat_atl          0       0.0
# 4  28.3617 -97.7476       NaN       NaN         NaN          0       0.0
#
#    usa_lat  usa_lon usa_status  usa_wind  usa_pres  usa_sshs  usa_eye  \
# ...

# %%
df.isnull().sum()
# Out:
# sid                0
# season             0
# number             0
# name               0
# iso_time           0
# nature             0
# lat                0
# lon                0
# wmo_wind        7575
# wmo_pres       11414
# wmo_agency      7560
# dist2land          0
# landfall           0
# usa_lat         1296
# usa_lon         1296
# usa_status      1253
# usa_wind        1368
# usa_pres        8941
# usa_sshs         137
# usa_eye        14209
# usa_seahgt     13764
# storm_speed        0
# storm_dir          0
# dtype: int64

# %%
df.shape
# Out:
# (14214, 23)

# %%
df['usa_status'].unique()
# Out:
# array(['HU', 'TS', nan, 'EX', 'TD', 'LO', 'DB', 'SD', 'SS', 'ET', 'WV'],
#       dtype=object)

# %%
storm_status = {
    "DB" : "disturbance",
    "TD" : "tropical depression",
    "TS" : "tropical storm",
    "TY" : "typhoon",
    "ST" : "super typhoon",
    "TC" : "tropical cyclone",
    "HU" : "hurricane",
    "HR" : "hurricane",
    "SD" : "subtropical depression",
    "SS" : "subtropical storm",
    "EX" : "extratropical systems",
    "PT" : "post tropical",
    "IN" : "inland",
    "DS" : "dissipating",
    "LO" : "low",
    "WV" : "tropical wave",
    "ET" : "extrapolated",
    "MD" : "monsoon depression"
}
new_values = {
    "usa_status" : storm_status
}
def rename_values(df, dictionary):
    for k,v in dictionary.items():
        df[k] = df[k].map(v)

# %%
df.head()
# Out:
#              sid  season  number       name             iso_time nature  \
# 0  1851175N26270    1851       5  NOT_NAMED  1851-06-25 21:00:00     TS
# 1  1851175N26270    1851       5  NOT_NAMED  1851-06-26 00:00:00     TS
# 2  1851175N26270    1851       5  NOT_NAMED  1851-06-26 03:00:00     TS
# 3  1851175N26270    1851       5  NOT_NAMED  1851-06-26 06:00:00     TS
# 4  1851175N26270    1851       5  NOT_NAMED  1851-06-26 09:00:00     TS
#
#        lat      lon  wmo_wind  wmo_pres  wmo_agency  dist2land  landfall  \
# 0  28.1333 -96.5667      80.0       NaN  hurdat_atl         22       0.0
# 1  28.1667 -96.8000      70.0       NaN  hurdat_atl          0       0.0
# 2  28.2265 -97.0793       NaN       NaN         NaN          0       0.0
# 3  28.3000 -97.4000      60.0       NaN  hurdat_atl          0       0.0
# 4  28.3617 -97.7476       NaN       NaN         NaN          0       0.0
#
#    usa_lat  usa_lon usa_status  usa_wind  usa_pres  usa_sshs  usa_eye  \
# ...

# %%
df['landfall'] = df['landfall'].map(float)
df["lon"] = df["lon"].map(float)
df["lat"] = df["lat"].map(float)
df = df[df['landfall'] == 0]
df = df[df['lon'] < -35]
df = df[df["lat"] < 60]
df = df[df["lat"] > 23.5]

# %%
df.shape
# Out:
# (9933, 23)

# %%
df.isnull().sum()
# Out:
# sid               0
# season            0
# number            0
# name              0
# iso_time          0
# nature            0
# lat               0
# lon               0
# wmo_wind       5153
# wmo_pres       7872
# wmo_agency     5150
# dist2land         0
# landfall          0
# usa_lat         694
# usa_lon         694
# usa_status      649
# usa_wind        731
# usa_pres       6062
# usa_sshs        113
# usa_eye        9932
# usa_seahgt     9672
# storm_speed       0
# storm_dir         0
# dtype: int64

# %%
df = df.drop(columns = ['usa_eye', 'number', 'usa_seahgt'] )

# %%
#new_df[new_df['name']=='SANDY']

# %%
df.shape
# Out:
# (9933, 20)

# %%
def state_column(df1, df2, col1, new_column = None):
    # empty list
    location_dict = {}
    # iterate through hurricane points
    for point_index, point in df1["geometry"].iteritems():
        # iterate through our location dataframe
        for index, location in df2["geometry"].iteritems():
            if point.within(location) == True:
                location_dict[point_index] = df2[col1][index]
#     df1[new_column] = location_list       
    return location_dict
